# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Addresses.csv',
#  'addresses.txt',
#  'Addresses.xlsx',
#  'dictionary.json',
#  'intro_pandas.ipynb',
#  'reading_files.ipynb',
#  'Scrapper.ipynb']

# %%
import pandas

df = pandas.read_csv("Addresses.csv")
df
# Out:
#                                           Address  \
# 0       School of Economics and Development Legon
# 1                     School of Engineering Legon
# 2    School of performing Arts new building legon
# 3      Univiersity of Ghana Business School Legon
# 4                           Faculty of Arts Legon
# ..                                            ...
# 115         International Programmes Office Legon
# 116            University of Ghana Bookshop Legon
# 117                  Caregie Writing Centre Legon
# 118                       Basketball courts Legon
# 119                Recreational Quandrangle Legon
#
#      School of Economics and Development Legon  School of Engineering Legon  \
# 0                                     0.000000                     0.768476
# 1                                     0.768476                     0.000000
# 2                                     0.711333                     0.675567
# ...

# %%
#............TEXT......................................
df = pandas.read_csv("addresses.txt")
df
# Out:
#                  School of Economics and Development   Legon
# 0                              School of Engineering   Legon
# 1             School of performing Arts new building   legon
# 2               Univiersity of Ghana Business School   Legon
# 3                                    Faculty of Arts   Legon
# 4    School of information and communication studies   Legon
# ..                                               ...     ...
# 119                  International Programmes Office   Legon
# 120                     University of Ghana Bookshop   Legon
# 121                           Caregie Writing Centre   Legon
# 122                                Basketball courts   Legon
# 123                         Recreational Quandrangle   Legon
#
# [124 rows x 2 columns]

# %%
# dir(pandas)#

# %%
df3 = pandas.read_excel("Addresses.xlsx")
df3
# Out:
#                  Radius of the Earth (km)              6378.1  \
# 0                                      NaN                NaN
# 1                                      NaN                NaN
# 2                                      NaN                NaN
# 3                                      NaN                NaN
# 4                                  Address  Latitude(degrees)
# ..                                     ...                ...
# 123  International Programmes Office Legon           5.653574
# 124     University of Ghana Bookshop Legon           5.650991
# 125           Caregie Writing Centre Legon           5.650804
# 126                Basketball courts Legon           5.635578
# 127         Recreational Quandrangle Legon           5.652934
#
#              Unnamed: 2         Unnamed: 3          Unnamed: 4  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# ...
